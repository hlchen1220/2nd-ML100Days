# %% [markdown]
# # 作業1:
# 選擇 房價預測- https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview
# 1. 你選的這組資料為何重要
#    答: 可影響個人購屋換屋判斷, 亦是建商建屋時機, 定價決策依據, 也可做為政府政策(稅賦, 營建執照發放)依據
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     答: 提供者為Truman State University的Dean De Cock於2011發表, 收集了2006-2010Ames的房子資訊, 第一版來自於IOWA State University學生論文的Boston Housing Data Set.
# 3. 蒐集而來的資料型態為何
#     答: 結構化資料, 以.csv儲存
# 4. 這組資料想解決的問題如何評估
#     答: RMSE between the logarithm of the predicted value and the logarithm of the observed sales price

# %% [markdown]
# # 作業2:
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     答: 假設能準確知道乘客移動的時間與路徑將能讓車隊減少等待且增加載客數. 評估方式, 超過一半的司機可增加業績
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     答: 手機移動訊號經緯度, 公司上下班時間, 大眾運輸運次與發車時間, 各縣市擁有自用車以及使用比例, 車隊業者數及從業人數, 載客點位置
# 3. 蒐集而來的資料型態為何
#     答: 電信商, 政府公開資訊
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     答: 分類問題, binary cross-entropy?

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    mse = MSE = sum(abs(y - y_hat)**2) / len(y)
    return mse

MSE = mean_squared_error(y,y_hat)
print('MSE is %.3f' % (MSE))
# Out:
# MSE is 222.370

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.073

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 214.269
# The Mean absolute error is 11.902
